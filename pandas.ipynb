# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravikanth45/appllab/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Introduction pandas**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
Dataset= pd.read_excel('/content/drive/MyDrive/rkdatasets/CARS_1.csv')
Dataset
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-db00e00d27cf> in <cell line: 1>()
# ----> 1 Dataset= pd.read_excel('/content/drive/MyDrive/rkdatasets/CARS_1.csv')
#       2 Dataset
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# # **Indexing Slicing**

# %%
Dataset.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b3a7de197655> in <cell line: 1>()
# ----> 1 Dataset.head()
#
# NameError: name 'Dataset' is not defined

# %%
Dataset.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4390ba6e4dc0> in <cell line: 1>()
# ----> 1 Dataset.head(10)
#
# NameError: name 'Dataset' is not defined

# %%
Dataset.head(2)
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
#
#    Data Science  Artificial Intelligence
# 0            86                       69
# 1            93                       70

# %%
Dataset.head(7)
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
# 3      204               Latha          98    98      96                77
# 4      205                Rani          87    87      87                92
# 5      206              Jyothi          89    89      82                69
# 6      207             Krishna          90    94      85                68
#
#    Data Science  Artificial Intelligence
# 0            86                       69
# 1            93                       70
# 2            89                       86
# 3            98                       90
# 4            87                       96
# 5            89                       86
# 6            94                       93

# %%
Dataset.tail()
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 34      236             Jeevana          85    78      99                88
# 35      237              Ganesh          96    92      87                92
# 36      238           Poorinima          92    77      73                77
# 37      239            Manjusha          91    90      92                97
# 38      240            Nikhitha          93    68      91                69
#
#     Data Science  Artificial Intelligence
# 34            59                       77
# 35            60                       92
# 36            56                       69
# 37            70                       68
# 38            85                       78

# %%
Dataset.tail(10)
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 29      231              Devika          99    86      88                95
# 30      232                Isha          87    93      99                96
# 31      233              Apsara          73    89      87                87
# 32      234             Ankitha          66    94      85                82
# 33      235            Anuradha          84    95      88                85
# 34      236             Jeevana          85    78      99                88
# 35      237              Ganesh          96    92      87                92
# 36      238           Poorinima          92    77      73                77
# 37      239            Manjusha          91    90      92                97
# 38      240            Nikhitha          93    68      91                69
#
#     Data Science  Artificial Intelligence
# 29            87                       90
# 30            66                       94
# ...

# %%
.describe()Dataset
# Out:
#           Roll No  C Language       Java     Python  Machine Learning  \
# count   39.000000   39.000000  39.000000  39.000000         39.000000
# mean   220.641026   86.076923  88.102564  88.358974         87.051282
# std     11.808755    9.056503   6.870206   6.238620          8.309629
# min    201.000000   65.000000  68.000000  73.000000         68.000000
# 25%    210.500000   82.500000  85.500000  85.000000         82.500000
# 50%    221.000000   88.000000  88.000000  88.000000         88.000000
# 75%    230.500000   92.500000  93.000000  92.500000         93.000000
# max    240.000000   99.000000  99.000000  99.000000         99.000000
#
#        Data Science  Artificial Intelligence
# count     39.000000                39.000000
# mean      84.615385                87.128205
# std       11.242811                 8.348273
# min       56.000000                68.000000
# 25%       82.000000                85.500000
# 50%       87.000000                89.000000
# ...

# %%
Dataset.shape
# Out:
# (39, 8)

# %%
Dataset[0:10:2]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 2      203                 Ram          89    89      95                92
# 4      205                Rani          87    87      87                92
# 6      207             Krishna          90    94      85                68
# 8      209              Suresh          95    96      99                91
#
#    Data Science  Artificial Intelligence
# 0            86                       69
# 2            89                       86
# 4            87                       96
# 6            94                       93
# 8            96                       98

# %%
["Machine Learning"]Dataset
# Out:
# 0     95
# 1     78
# 2     92
# 3     77
# 4     92
# 5     69
# 6     68
# 7     78
# 8     91
# 9     83
# 10    95
# 11    96
# 12    87
# 13    82
# 14    85
# 15    88
# 16    99
# 17    87
# 18    73
# 19    92
# 20    91
# 21    93
# 22    86
# 23    93
# 24    89
# 25    98
# 26    87
# 27    89
# 28    94
# 29    95
# 30    96
# 31    87
# 32    82
# 33    85
# 34    88
# 35    92
# 36    77
# 37    97
# 38    69
# Name: Machine Learning, dtype: int64

# %%
Dataset["Java"]
# Out:
# 0     86
# 1     93
# 2     89
# 3     98
# 4     87
# 5     89
# 6     94
# 7     95
# 8     96
# 9     87
# 10    82
# 11    85
# 12    88
# 13    92
# 14    77
# 15    87
# 16    82
# 17    85
# 18    88
# 19    99
# 20    87
# 21    85
# 22    88
# 23    99
# 24    87
# 25    73
# 26    92
# 27    91
# 28    93
# 29    86
# 30    93
# 31    89
# 32    94
# 33    95
# 34    78
# 35    92
# 36    77
# 37    90
# 38    68
# Name: Java, dtype: int64

# %%
Dataset[["Python","Data Science"]]
# Out:
#     Python  Data Science
# 0       91            86
# 1       83            93
# 2       95            89
# 3       96            98
# 4       87            87
# 5       82            89
# 6       85            94
# 7       88            95
# 8       99            96
# 9       87            87
# 10      77            82
# 11      82            85
# 12      86            88
# 13      93            92
# 14      89            77
# 15      98            91
# 16      87            83
# 17      89            87
# 18      94            89
# 19      95            65
# 20      96            74
# 21      87            94
# 22      82            95
# 23      85            96
# 24      88            87
# 25      92            82
# 26      77            85
# 27      82            88
# 28      85            99
# 29      88            87
# 30      99            66
# 31      87            88
# 32      85            77
# 33      88            99
# 34      99            59
# 35      87            60
# ...

# %%
Dataset[["Python","Data Science","Artificial Intelligence"]]
# Out:
#     Python  Data Science  Artificial Intelligence
# 0       91            86                       69
# 1       83            93                       70
# 2       95            89                       86
# 3       96            98                       90
# 4       87            87                       96
# 5       82            89                       86
# 6       85            94                       93
# 7       88            95                       89
# 8       99            96                       98
# 9       87            87                       87
# 10      77            82                       89
# 11      82            85                       94
# 12      86            88                       95
# 13      93            92                       96
# 14      89            77                       87
# 15      98            91                       82
# 16      87            83                       85
# 17      89            87                       88
# ...

# %%
Dataset[["Python","Data Science","Artificial Intelligence"]][0:10:3]
# Out:
#    Python  Data Science  Artificial Intelligence
# 0      91            86                       69
# 3      96            98                       90
# 6      85            94                       93
# 9      87            87                       87

# %% [markdown]
# # **Iterrows**
#
# Iterrows displayed all columns in row order

# %%
for rec in Dataset.iterrows():
  print(rec)
# Out:
# (0, Roll No                     201
# Name of the Student        Hema
# C Language                   86
# Java                         86
# Python                       91
# Machine Learning             95
# Data Science                 86
# Artificial Intelligence      69
# Name: 0, dtype: object)
# (1, Roll No                     202
# Name of the Student        Hari
# C Language                   93
# Java                         93
# Python                       83
# Machine Learning             78
# Data Science                 93
# Artificial Intelligence      70
# Name: 1, dtype: object)
# (2, Roll No                    203
# Name of the Student        Ram
# C Language                  89
# Java                        89
# Python                      95
# Machine Learning            92
# Data Science                89
# Artificial Intelligence     86
# Name: 2, dtype: object)
# (3, Roll No                      204
# Name of the Student        Latha
# ...

# %% [markdown]
# ## **UNDERSTANDING LOC[]**
#
# (stop index included)

# %% [markdown]
# *  data_frame.loc[row_number]
# *  data_frame.loc[row_number,[ccolumn_name,...]]
# *  data_frame.loc[start:stop]
# *  data_frame.loc[start:stop,"column_name"]
# *  data_frame.loc[start:stop,["column_1,column_2,...."]]
# *  data_frame.loc[start:stop,"column_1":"column_n"]

# %%
Dataset.loc[1]
# Out:
# Roll No                     202
# Name of the Student        Hari
# C Language                   93
# Java                         93
# Python                       83
# Machine Learning             78
# Data Science                 93
# Artificial Intelligence      70
# Name: 1, dtype: object

# %%
Dataset.loc[15]
# Out:
# Roll No                       217
# Name of the Student        Ravali
# C Language                     78
# Java                           87
# Python                         98
# Machine Learning               88
# Data Science                   91
# Artificial Intelligence        82
# Name: 15, dtype: object

# %%
Dataset.loc[29]
# Out:
# Roll No                       231
# Name of the Student        Devika
# C Language                     99
# Java                           86
# Python                         88
# Machine Learning               95
# Data Science                   87
# Artificial Intelligence        90
# Name: 29, dtype: object

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %%
Dataset.loc[19,["Data Science"]]
# Out:
# Data Science    65
# Name: 19, dtype: object

# %%
Dataset.loc[10,["Python","Data Science","Artificial Intelligence"]]
# Out:
# Python                     77
# Data Science               82
# Artificial Intelligence    89
# Name: 10, dtype: object

# %%
Dataset.loc[0:3]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
# 3      204               Latha          98    98      96                77
#
#    Data Science  Artificial Intelligence
# 0            86                       69
# 1            93                       70
# 2            89                       86
# 3            98                       90

# %%
Dataset.iloc[0:3]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
#
#    Data Science  Artificial Intelligence
# 0            86                       69
# 1            93                       70
# 2            89                       86

# %%
Dataset.loc[0:5,"C Language"]
# Out:
# 0    86
# 1    93
# 2    89
# 3    98
# 4    87
# 5    89
# Name: C Language, dtype: int64

# %%
Dataset.loc[32:35,"Java"]
# Out:
# 32    94
# 33    95
# 34    78
# 35    92
# Name: Java, dtype: int64

# %%
Dataset.loc[0:5,["Machine Learning","Python"]]
# Out:
#    Machine Learning  Python
# 0                95      91
# 1                78      83
# 2                92      95
# 3                77      96
# 4                92      87
# 5                69      82

# %%
Dataset.loc[0:3,"C Language":"Data Science"] #range
# Out:
#    C Language  Java  Python  Machine Learning  Data Science
# 0          86    86      91                95            86
# 1          93    93      83                78            93
# 2          89    89      95                92            89
# 3          98    98      96                77            98

# %% [markdown]
# # **iloc()**
#
# * stop index value not also included
# * column position must indicated(not column name)

# %% [markdown]
# ## **UNDERSTANDING ILOC[]**
# (stop index excluded)

# %%
Dataset.iloc[0:3]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
#
#    Data Science  Artificial Intelligence
# 0            86                       69
# 1            93                       70
# 2            89                       86

# %%
Dataset.iloc[2,0]
# Out:
# 203

# %%
Dataset.iloc[3,5]
# Out:
# 77

# %%
Dataset.iloc[0:3,0:4]
# Out:
#    Roll No Name of the Student  C Language  Java
# 0      201                Hema          86    86
# 1      202                Hari          93    93
# 2      203                 Ram          89    89

# %%
Dataset.iloc[0:5,1]
# Out:
# 0     Hema
# 1     Hari
# 2      Ram
# 3    Latha
# 4     Rani
# Name: Name of the Student, dtype: object

# %%
Dataset.iloc[0:5,1]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
# 3      204               Latha          98    98      96                77
#
#    Data Science  Artificial Intelligence
# 1            93                       70
# 2            89                       86
# 3            98                       90

# %%
Dataset.iloc[[4,6,12,32]]
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 4       205                Rani          87    87      87                92
# 6       207             Krishna          90    94      85                68
# 12      213              Anusri          92    88      86                87
# 32      234             Ankitha          66    94      85                82
#
#     Data Science  Artificial Intelligence
# 4             87                       96
# 6             94                       93
# 12            88                       95
# 32            77                       78

# %%
Dataset.iloc[:,["Data Science"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-30da433754e3> in <cell line: 1>()
# ----> 1 Dataset.iloc[:,["Data Science"]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1561     def _getitem_tuple(self, tup: tuple):
#    1562
# -> 1563         tup = self._validate_tuple_indexer(tup)
#    1564         with suppress(IndexingError):
#    1565             return self._getitem_lowerdim(tup)
#
# ...

# %%
Dataset.loc[:,["Data Science"]]
# Out:
#     Data Science
# 0             86
# 1             93
# 2             89
# 3             98
# 4             87
# 5             89
# 6             94
# 7             95
# 8             96
# 9             87
# 10            82
# 11            85
# 12            88
# 13            92
# 14            77
# 15            91
# 16            83
# 17            87
# 18            89
# 19            65
# 20            74
# 21            94
# 22            95
# 23            96
# 24            87
# 25            82
# 26            85
# 27            88
# 28            99
# 29            87
# 30            66
# 31            88
# 32            77
# 33            99
# 34            59
# 35            60
# 36            56
# 37            70
# 38            85

# %%
Dataset.iloc[:,[1]]
# Out:
#    Name of the Student
# 0                 Hema
# 1                 Hari
# 2                  Ram
# 3                Latha
# 4                 Rani
# 5               Jyothi
# 6              Krishna
# 7                 Raju
# 8               Suresh
# 9              Sandhya
# 10             Sameera
# 11            Santhosh
# 12              Anusri
# 13              Bhavya
# 14             Lakshmi
# 15              Ravali
# 16               Meena
# 17              Kalyan
# 18              Charan
# 19               Arjun
# 20                Niha
# 21             Neeraja
# 22                Devi
# 23               Bindu
# 24            Bhargavi
# 25             Nandini
# 26             Syamala
# 27             Sumanth
# 28             Subhash
# 29              Devika
# 30                Isha
# 31              Apsara
# 32             Ankitha
# 33            Anuradha
# 34             Jeevana
# 35              Ganesh
# 36           Poorinima
# 37            Manjusha
# 38            Nikhitha

# %% [markdown]
# *italicised text*(:) indicates all rows
#
# > Indented block

# %%
Dataset.iloc[:,[1,2]]
# Out:
#    Name of the Student  C Language
# 0                 Hema          86
# 1                 Hari          93
# 2                  Ram          89
# 3                Latha          98
# 4                 Rani          87
# 5               Jyothi          89
# 6              Krishna          90
# 7                 Raju          94
# 8               Suresh          95
# 9              Sandhya          78
# 10             Sameera          92
# 11            Santhosh          77
# 12              Anusri          92
# 13              Bhavya          69
# 14             Lakshmi          68
# 15              Ravali          78
# 16               Meena          91
# 17              Kalyan          83
# 18              Charan          87
# 19               Arjun          89
# 20                Niha          65
# 21             Neeraja          74
# 22                Devi          94
# 23               Bindu          95
# 24            Bhargavi          96
# 25             Nandini          87
# ...

# %%
Dataset.iloc[:,[1,2,3]]
# Out:
#    Name of the Student  C Language  Java
# 0                 Hema          86    86
# 1                 Hari          93    93
# 2                  Ram          89    89
# 3                Latha          98    98
# 4                 Rani          87    87
# 5               Jyothi          89    89
# 6              Krishna          90    94
# 7                 Raju          94    95
# 8               Suresh          95    96
# 9              Sandhya          78    87
# 10             Sameera          92    82
# 11            Santhosh          77    85
# 12              Anusri          92    88
# 13              Bhavya          69    92
# 14             Lakshmi          68    77
# 15              Ravali          78    87
# 16               Meena          91    82
# 17              Kalyan          83    85
# 18              Charan          87    88
# 19               Arjun          89    99
# 20                Niha          65    87
# 21             Neeraja          74    85
# ...

# %%
Dataset.iloc[0:2,[1,2,3]]
# Out:
#   Name of the Student  C Language  Java
# 0                Hema          86    86
# 1                Hari          93    93

# %%
Dataset.iloc[0:4,[1,5,7]]
# Out:
#   Name of the Student  Machine Learning  Artificial Intelligence
# 0                Hema                95                       69
# 1                Hari                78                       70
# 2                 Ram                92                       86
# 3               Latha                77                       90

# %%
Dataset.iloc[1:8,[1,3,6]]
# Out:
#   Name of the Student  Java  Data Science
# 1                Hari    93            93
# 2                 Ram    89            89
# 3               Latha    98            98
# 4                Rani    87            87
# 5              Jyothi    89            89
# 6             Krishna    94            94
# 7                Raju    95            95

# %%
Dataset.iloc[[1,2,3],[1,3,5]]
# Out:
#   Name of the Student  Java  Machine Learning
# 1                Hari    93                78
# 2                 Ram    89                92
# 3               Latha    98                77

# %%
Dataset.iloc[[32,34,36],[1,4,7]]
# Out:
#    Name of the Student  Python  Artificial Intelligence
# 32             Ankitha      85                       78
# 34             Jeevana      99                       77
# 36           Poorinima      73                       69

# %% [markdown]
# # **Sorting DataFrame**

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %%
Dataset.sort_values("Python")
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 36      238           Poorinima          92    77      73                77
# 26      228             Syamala          82    92      77                87
# 10      211             Sameera          92    82      77                95
# 22      224                Devi          94    88      82                86
# 5       206              Jyothi          89    89      82                69
# 27      229             Sumanth          85    91      82                89
# 11      212            Santhosh          77    85      82                96
# 1       202                Hari          93    93      83                78
# 23      225               Bindu          95    99      85                93
# 6       207             Krishna          90    94      85                68
# 28      230             Subhash          88    93      85                94
# ...

# %% [markdown]
# * If ascending order=false means,particular column values will be displayed in descending order.

# %%
.sort_values("Python",ascending=False) #ascending order=False(DesceDatasetnding order)
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 34      236             Jeevana          85    78      99                88
# 30      232                Isha          87    93      99                96
# 8       209              Suresh          95    96      99                91
# 15      217              Ravali          78    87      98                88
# 3       204               Latha          98    98      96                77
# 20      222                Niha          65    87      96                91
# 19      221               Arjun          89    99      95                92
# 2       203                 Ram          89    89      95                92
# 18      220              Charan          87    88      94                73
# 13      214              Bhavya          69    92      93                82
# 37      239            Manjusha          91    90      92                97
# ...

# %% [markdown]
# * If we  giving no.of columns at a time,but it sorted first mentioned only.

# %%
Dataset.sort_values(["Java","C Language"])
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 38      240            Nikhitha          93    68      91                69
# 25      227             Nandini          87    73      92                98
# 14      216             Lakshmi          68    77      89                85
# 36      238           Poorinima          92    77      73                77
# 34      236             Jeevana          85    78      99                88
# 16      218               Meena          91    82      87                99
# 10      211             Sameera          92    82      77                95
# 21      223             Neeraja          74    85      87                93
# 11      212            Santhosh          77    85      82                96
# 17      219              Kalyan          83    85      89                87
# 0       201                Hema          86    86      91                95
# ...

# %%
Dataset.sort_values(["Artificial Intelligence","Machine Learning"])
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 37      239            Manjusha          91    90      92                97
# 36      238           Poorinima          92    77      73                77
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 34      236             Jeevana          85    78      99                88
# 19      221               Arjun          89    99      95                92
# 38      240            Nikhitha          93    68      91                69
# 32      234             Ankitha          66    94      85                82
# 15      217              Ravali          78    87      98                88
# 16      218               Meena          91    82      87                99
# 5       206              Jyothi          89    89      82                69
# ...

# %% [markdown]
# #****Manipulating  Data Frame****

# %% [markdown]
# **ADDING COLUMN**
# *  Data_frame['new_col_name']=default_value
# *  Data_frame['new_col_name']=Expression/Condition
#
# **REMOVING COLUMN**
# *  Data_frame.drop(columns="column_name")
# *  Data-frame.drop("columns=column_name",inplace=True)

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %%
Dataset["Artificial Intelligence"]=0

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %%
Dataset["Artificial Intelligence"]=Dataset["C Language"]+Dataset["Python"]+Dataset["Java"]

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %%
Dataset["Artificial Intelligence"]="orange/apple"

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %%
Dataset.drop(columns="Artificial Intelligence")  #temporarly deleted
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %% [markdown]
# * inplace = True, means particular column will be deleted permanently.

# %%
Dataset.drop(columns="Artificial Intelligence", inplace=True) #perminently that particular coloum will be deleted

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %% [markdown]
# #****Removing Duplicates****

# %% [markdown]
# **Knowning Duplicates**
# * Data_frame.duplicatelean Result Removing Duplicates
# * Data_frame.drop_d() -Booduplicates()
# * Data_frame.drop_duplicates(inplace=true)
#
# & If duplicates are present in the dataset, output shows true otherwise false

# %%
Dataset.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# dtype: bool

# %%
Dataset=pd.read_excel('/content/drive/MyDrive/DATASETS/Student Marks Duplicate.xlsx')

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# dtype: bool

# %%
Dataset.drop_duplicates() #temporarly deleted
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset.drop_duplicates(inplace=True) #permanently deleted

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %% [markdown]
# #**Handling Missing Data**

# %%
Dataset=pd.read_excel('/content/drive/MyDrive/DATASETS/Student Marks Missing.xlsx')

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema        86.0  86.0    91.0              95.0
# 1       202                Hari        93.0  93.0    83.0              78.0
# 2       203                 Ram         NaN  89.0    95.0              92.0
# 3       204               Latha        98.0  98.0     NaN              77.0
# 4       205                Rani        87.0  87.0    87.0              92.0
# 5       206              Jyothi        89.0  89.0    82.0              69.0
# 6       207             Krishna        90.0  94.0    85.0              68.0
# 7       208                Raju        94.0   NaN    88.0               NaN
# 8       209              Suresh        95.0  96.0    99.0              91.0
# 9       214              Bhavya         NaN  92.0    93.0              82.0
# 10      210             Sandhya        78.0  87.0    87.0              83.0
# ...

# %%
Dataset["Python"].fillna(90)  #empty spaces filled with 90
# Out:
# 0     91.0
# 1     83.0
# 2     95.0
# 3     90.0
# 4     87.0
# 5     82.0
# 6     85.0
# 7     88.0
# 8     99.0
# 9     93.0
# 10    87.0
# 11    90.0
# 12    82.0
# 13    86.0
# 14    93.0
# 15    89.0
# 16    98.0
# 17    87.0
# 18    85.0
# 19    90.0
# 20    88.0
# 21    94.0
# 22    95.0
# 23    90.0
# 24    87.0
# 25    82.0
# 26    85.0
# 27    88.0
# 28    92.0
# 29    77.0
# 30    82.0
# 31    85.0
# 32    88.0
# 33    99.0
# 34    87.0
# 35    85.0
# 36    88.0
# 37    99.0
# 38    87.0
# 39    73.0
# 40    92.0
# 41    91.0
# Name: Python, dtype: float64

# %%
Dataset.fillna(90) #empty values filled with 90
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema        86.0  86.0    91.0              95.0
# 1       202                Hari        93.0  93.0    83.0              78.0
# 2       203                 Ram        90.0  89.0    95.0              92.0
# 3       204               Latha        98.0  98.0    90.0              77.0
# 4       205                Rani        87.0  87.0    87.0              92.0
# 5       206              Jyothi        89.0  89.0    82.0              69.0
# 6       207             Krishna        90.0  94.0    85.0              68.0
# 7       208                Raju        94.0  90.0    88.0              90.0
# 8       209              Suresh        95.0  96.0    99.0              91.0
# 9       214              Bhavya        90.0  92.0    93.0              82.0
# 10      210             Sandhya        78.0  87.0    87.0              83.0
# ...

# %%
Dataset.dropna() #Missing records are deleted
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema        86.0  86.0    91.0              95.0
# 1       202                Hari        93.0  93.0    83.0              78.0
# 4       205                Rani        87.0  87.0    87.0              92.0
# 5       206              Jyothi        89.0  89.0    82.0              69.0
# 6       207             Krishna        90.0  94.0    85.0              68.0
# 8       209              Suresh        95.0  96.0    99.0              91.0
# 12      212            Santhosh        77.0  85.0    82.0              96.0
# 18      207             Krishna        90.0  94.0    85.0              68.0
# 20      226            Bhargavi        96.0  87.0    88.0              89.0
# 21      220              Charan        87.0  88.0    94.0              73.0
# 25      224                Devi        94.0  88.0    82.0              86.0
# ...

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema        86.0  86.0    91.0              95.0
# 1       202                Hari        93.0  93.0    83.0              78.0
# 2       203                 Ram         NaN  89.0    95.0              92.0
# 3       204               Latha        98.0  98.0     NaN              77.0
# 4       205                Rani        87.0  87.0    87.0              92.0
# 5       206              Jyothi        89.0  89.0    82.0              69.0
# 6       207             Krishna        90.0  94.0    85.0              68.0
# 7       208                Raju        94.0   NaN    88.0               NaN
# 8       209              Suresh        95.0  96.0    99.0              91.0
# 9       214              Bhavya         NaN  92.0    93.0              82.0
# 10      210             Sandhya        78.0  87.0    87.0              83.0
# ...

# %%
#automatmat)
#automatmat)

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema        86.0  86.0    91.0              95.0
# 1       202                Hari        93.0  93.0    83.0              78.0
# 4       205                Rani        87.0  87.0    87.0              92.0
# 5       206              Jyothi        89.0  89.0    82.0              69.0
# 6       207             Krishna        90.0  94.0    85.0              68.0
# 8       209              Suresh        95.0  96.0    99.0              91.0
# 12      212            Santhosh        77.0  85.0    82.0              96.0
# 18      207             Krishna        90.0  94.0    85.0              68.0
# 20      226            Bhargavi        96.0  87.0    88.0              89.0
# 21      220              Charan        87.0  88.0    94.0              73.0
# 25      224                Devi        94.0  88.0    82.0              86.0
# ...

# %% [markdown]
# #**Data Filtering And Conditional Changes**

# %% [markdown]
# Simple Condition
#
# Data_frame["col_name"]>/</==value

# %%
Dataset=pd.read_excel('/content/drive/MyDrive/DATASETS/Student Marks.csv.xlsx')

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %%
Dataset.loc[Dataset["Python"]>90]  #python greater than 90 marks will be displayed
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 8       209              Suresh          95    96      99                91
# 13      214              Bhavya          69    92      93                82
# 15      217              Ravali          78    87      98                88
# 18      220              Charan          87    88      94                73
# 19      221               Arjun          89    99      95                92
# 20      222                Niha          65    87      96                91
# 25      227             Nandini          87    73      92                98
# 30      232                Isha          87    93      99                96
# ...

# %%
Dataset.loc[Dataset["Java"]>90]
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 1       202                Hari          93    93      83                78
# 3       204               Latha          98    98      96                77
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 13      214              Bhavya          69    92      93                82
# 19      221               Arjun          89    99      95                92
# 23      225               Bindu          95    99      85                93
# 26      228             Syamala          82    92      77                87
# 27      229             Sumanth          85    91      82                89
# 28      230             Subhash          88    93      85                94
# ...

# %%
Dataset.loc[(Dataset["C Language"]>90) & (Dataset["Python"]<85)]  #compound condition
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 1       202                Hari          93    93      83                78
# 10      211             Sameera          92    82      77                95
# 22      224                Devi          94    88      82                86
# 36      238           Poorinima          92    77      73                77
#
#     Data Science  Artificial Intelligence
# 1             93                       70
# 10            82                       89
# 22            95                       87
# 36            56                       69

# %%
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 4       205                Rani          87    87      87                92
# 6       207             Krishna          90    94      85                68
# 9       210             Sandhya          78    87      87                83
# 11      212            Santhosh          77    85      82                96
# 12      213              Anusri          92    88      86                87
# 16      218               Meena          91    82      87                99
# 17      219              Kalyan          83    85      89                87
# 18      220              Charan          87    88      94                73
# 19      221               Arjun          89    99      95                92
# 23      225               Bindu          95    99      85                93
# 25      227             Nandini          87    73      92                98
# ...

# %%
Dataset.loc[Dataset["Name of the Student"].str.startswith("h")]
# Out:
# Empty DataFrame
# Columns: [Roll No, Name of the Student, C Language, Java, Python, Machine Learning, Data Science, Artificial Intelligence]
# Index: []

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %%
Dataset.loc[Dataset["Name of the Student"].str.startswith("H")]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
#
#    Data Science  Artificial Intelligence
# 0            86                       69
# 1            93                       70

# %%
Dataset.loc[Dataset["Name of the Student"].str.startswith("R")]
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 2       203                 Ram          89    89      95                92
# 4       205                Rani          87    87      87                92
# 7       208                Raju          94    95      88                78
# 15      217              Ravali          78    87      98                88
#
#     Data Science  Artificial Intelligence
# 2             89                       86
# 4             87                       96
# 7             95                       89
# 15            91                       82

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       210             Sandhya          78    87      87                83
# 10      211             Sameera          92    82      77                95
# ...

# %%
Dataset["Python"]=(Dataset["Java"]/20)+50

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86   54.30                95
# 1       202                Hari          93    93   54.65                78
# 2       203                 Ram          89    89   54.45                92
# 3       204               Latha          98    98   54.90                77
# 4       205                Rani          87    87   54.35                92
# 5       206              Jyothi          89    89   54.45                69
# 6       207             Krishna          90    94   54.70                68
# 7       208                Raju          94    95   54.75                78
# 8       209              Suresh          95    96   54.80                91
# 9       210             Sandhya          78    87   54.35                83
# 10      211             Sameera          92    82   54.10                95
# ...
